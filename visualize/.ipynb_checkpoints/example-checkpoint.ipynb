# %%
# %matplotlib inline 
import matplotlib
from IPython.display import HTML

# %%
import utils

# %%
path_true = '/home/chengxuz/true_results_physics_pred_better_8.pkl' #Path to true results pkl
path_pred = '/home/chengxuz/results_physics_pred_better_8.pkl' # Path to prediction results pkl

reload(utils)
v_true, v_pred = utils.vis_true_and_pred(path_true, path_pred, ex=1) # ex is which example to visualize
# Out:
# 10
# 10

# %%
HTML(v_true)
# Out:
# <video width="288" height="288" controls autoplay loop style="display:block; margin: 0 auto;">
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
HTML(v_pred)
# Out:
# <video width="288" height="288" controls autoplay loop style="display:block; margin: 0 auto;">
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
